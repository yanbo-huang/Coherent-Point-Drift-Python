# %%
from __future__ import (absolute_import, division, print_function, unicode_literals)
from builtins import *

import cpd_affine as register_affine
import cpd_rigid as register_rigid
import register_nonrigid
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-53ca4ca42f73> in <module>()
#       2 from builtins import *
#       3
# ----> 4 import cpd_affine as register_affine
#       5 import cpd_rigid as register_rigid
#       6 import register_nonrigid
#
# C:\Users\Yanbo Huang\Documents\Mydocument\TUD courses\Medical Visualization\project local\cpd\cpd_affine.py in <module>()
#       3
#       4 import numpy as np
# ----> 5 from cpd.cpd_p import cpd_p
#       6
#       7
#
# ImportError: No module named cpd.cpd_p
